# %% [markdown]
# <!--<div align="center">Семинар № 2-->
#
# <div align="center"><font color=#1E90FF size=4 face=
#                           "arial black"><em><strong>Промежуточная аттестация.</strong></em></font></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>1.1</b>
# Создайте функцию, которая принимает кол-во сек и<br>
#     форматирует их в кол-во дней, часов, минут и секунд.<br>
# Пример: 123456 ->'1 days 10 hours 17 minutes 36 seconds'.
# </em></div>

# %% [markdown]
# ![hw_6_1.png](attachment:hw_6_1.png)

# %% [markdown]
# ***

# %% [markdown]
# ![hw_6_11.png](attachment:hw_6_11.png)

# %% [markdown]
# ***

# %% [markdown]
# ![hw_6_12.png](attachment:hw_6_12.png)

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>2.</b>
# Выведите только четные числа от 1 до 10 включительно.<br>
# Пример: 2,4,6,8,10 (можно сделать через шаг +  2: х = 2, х+=2).
# </em></div>

# %% [markdown]
# ![hw_6_21.png](attachment:hw_6_21.png)

# %% [markdown]
# ***

# %% [markdown]
# ![hw_6_22.png](attachment:hw_6_22.png)

# %% [markdown]
# ***

# %% [markdown]
# ![hw_6_23.png](attachment:hw_6_23.png)

# %% [markdown]
# ***
